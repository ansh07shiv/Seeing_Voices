# %%
import subscene

# %%
subscene.

# %%
myList = []

# %%
for var in film.subtitles:
    myList.append(var)

# %%
for var in myList:
    print(var.url)
# Out:
# https://subscene.com/subtitles/ex-machina/arabic/1141161
# https://subscene.com/subtitles/ex-machina/arabic/1143574
# https://subscene.com/subtitles/ex-machina/arabic/1141161
# https://subscene.com/subtitles/ex-machina/arabic/1115926
# https://subscene.com/subtitles/ex-machina/arabic/1115457
# https://subscene.com/subtitles/ex-machina/arabic/1141161
# https://subscene.com/subtitles/ex-machina/arabic/1115926
# https://subscene.com/subtitles/ex-machina/arabic/1115457
# https://subscene.com/subtitles/ex-machina/arabic/1141161
# https://subscene.com/subtitles/ex-machina/arabic/1115926
# https://subscene.com/subtitles/ex-machina/arabic/1115457
# https://subscene.com/subtitles/ex-machina/arabic/1115457
# https://subscene.com/subtitles/ex-machina/arabic/1115457
# https://subscene.com/subtitles/ex-machina/arabic/1115457
# https://subscene.com/subtitles/ex-machina/arabic/1141161
# https://subscene.com/subtitles/ex-machina/arabic/1115926
# ...

# %%
del subtitle

# %%
subtitle = film.subtitles[0]

# %%
subtitle

# %%
type(subtitle)
# Out:
# subscene.Subtitle

# %%
subtitle.language
# Out:
# 'Arabic'

# %%
subtitle.title
# Out:
# 'Original DVD Subtitle! IDX.'

# %%
subtitle.url
# Out:
# 'https://subscene.com/subtitles/ex-machina/arabic/1141161'
